# %% [markdown]
# # Lab 07: Spectrogram

# %%
# %matplotlib inline

import sys
sys.path.append('../ThinkDsp')
import thinkdsp
import thinkplot

# %% [markdown]
# ## Linear chirp

# %%
signal1 = thinkdsp.Chirp(start=220, end=880)
wave1 = signal1.make_wave(duration=2)

# %%
wave1.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Notice that the pitch rises quickly at first and then slows down

# %%
wave1.plot()

# %%
wave1.segment(0,0.05).plot()

# %%
wave1.segment(1,0.05).plot()

# %%
wave1.segment(1.9,0.05).plot()

# %%
sp1 = wave1.make_spectrum()
sp1.plot(high=1500)

# %% [markdown]
# Spectrum cannot show the relationship between frequency and time

# %%
sg1 = wave1.make_spectrogram(seg_length=2048)
sg1.plot(high=1000, shading='auto')

# %% [markdown]
# ## Exponential chirp

# %%
signal2 = thinkdsp.ExpoChirp(start=220, end=880)
wave2 = signal2.make_wave(duration=2)

# %%
wave2.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sg2 = wave2.make_spectrogram(seg_length=2048)
sg2.plot(high=1000, shading='auto')

# %%
sg2a = wave2.make_spectrogram(seg_length=4096)
sg2a.plot(high=1000, shading='auto')

# %% [markdown]
# ## String instrument - cello

# %%
wave3 = thinkdsp.read_wave('cello.wav')
wave3.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave3.plot()

# %%
sg3 = wave3.make_spectrogram(seg_length=4096)
sg3.plot(high=1000, shading='auto')

# %% [markdown]
# ## Gaussian noise

# %%
signal4 = thinkdsp.UncorrelatedGaussianNoise()
wave4 = signal4.make_wave(duration=2, framerate=11025)
wave4.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave4.plot()

# %%
sg4 = wave4.make_spectrogram(seg_length=4096)
sg4.plot(shading='auto')

# %% [markdown]
# ## Pink noise

# %%
signal5 = thinkdsp.PinkNoise()
wave5 = signal5.make_wave(duration=2, framerate=11025)
wave5.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave5.plot()

# %%
sg5 = wave5.make_spectrogram(seg_length=4096)
sg5.plot(high=100, shading='auto')

# %% [markdown]
# ## Voice

# %%
wave6 = thinkdsp.read_wave('voice.wav')
wave6.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave6.plot()

# %%
sg6 = wave6.make_spectrogram(seg_length=4096)
sg6.plot(high=3000, shading='auto')

# %%
wave6a = wave6.segment(0.05,0.3)
wave6a.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sg6a = wave6a.make_spectrogram(seg_length=1024)
sg6a.plot(high=6000, shading='auto')

# %% [markdown]
# ## Handclap

# %%
wave7 = thinkdsp.read_wave('handclap.wav')
wave7.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave7.plot()

# %%
sg7 = wave7.make_spectrogram(seg_length=2048)
sg7.plot(high=3000, shading='auto')

# %%
sg7a = wave7.segment(0.04,0.13).make_spectrogram(seg_length=256)
sg7a.plot(high=3000, shading='auto')

# %% [markdown]
# ## Drum

# %%
wave8 = thinkdsp.read_wave('drum.wav')
wave8.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave8.plot()

# %%
sg8 = wave8.make_spectrogram(seg_length=4096)
sg8.plot(high=200, shading='auto')
